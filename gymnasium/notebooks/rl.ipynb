# %%
def_min, def_max, tar_min, tar_max = 0, 1, -2, 4

def f(x):
  scale_factor = (tar_max - tar_min) / (def_max - def_min)

  print(scale_factor)

  return scale_factor * (x - def_min) + tar_min

f(def_min), f(def_max), f(0.5*(def_max-def_min))
# Out:
# 6.0
# 6.0
# 6.0
# (-2.0, 4.0, 1.0)

# %%
f(-1)
